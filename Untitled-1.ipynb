# %%
import csv
import os
#===========================================
(Data Loading & Cleanig )
#==========================
def load_data(filepath):
    date= []
    ifnot os.path.exists(filepath):
print (f"Frror:File not found at {filepath}")
return date 
with open(filepath,  mode='r,encoding='utf-8')as file:
    reader = csv. DictReader(file)
    for row in reader:
        try:
            processed_ row={
            'customer_id' :row['customer_id'].strip(),
            'region':row['region'].strep(),
            'plan_type':row ['plan_type'].streip(),
            'monthly_fee_sar':float(row['monthly_fee_sar'])if row['monthly_fee_sar']else 0.0,
            'tenure_months':imt (row['tenure_months'])if row ['tenure_months']else 0,
            'avg_date_gb_prior_3mo':float(row['avg_date_gb_prior_3mo'])if row ['avg_date_gb_prior_3mo']else 0.0,
            'avg_data_gb_recent_3mo':float(row['avg_date_gb_recent_3mo'])if row['avg_date_gb_recent_3mo']else 0,
            'support_calls_last_3mo': int {row['support_calls_last_3mo']}if row['support_calls_last_3mo']else 0,
            'late_payments_last_6mo':int {row['late_payments_last_6mo']}if row ['late_payments_last_6mo']else 0,
            'contacted_competitor_offer':row['contacted_compertitor_offer'].strip().lower()in['yes','true','1']
            }
            date.append(processed_row)
            except ValueError as e:
                continue
                return data 
                #================================================================================================================
                (Q1 & Q20)
                #================================================================================================================
                def calculate_metrics_and_scores(customers):
